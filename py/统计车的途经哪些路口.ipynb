# %%
import simpy, time, pickle
import pandas as pd
import numpy as np

# %%
with open('df', 'rb') as f:
    df = pickle.load(f)
df.head()
# Out:
#                              vehicle-id        time   x-coordinate  \
# 29194  c243b97c579b441827b59ade5f9c5c3b  1493852410  521579.616152
# 24479  f9643897f57a000c2facc2fe39de8947  1493852411  521461.647074
# 29195  c243b97c579b441827b59ade5f9c5c3b  1493852413  521575.164460
# 24480  f9643897f57a000c2facc2fe39de8947  1493852414  521466.098708
# 29196  c243b97c579b441827b59ade5f9c5c3b  1493852416  521570.712769
#
#        y-coordinate  speed  category  time2
# 29194  57525.893385    9.2         1      0
# 24479  56693.716517    7.2         1      1
# 29195  57498.213683    9.3         1      3
# 24480  56716.931752    7.8         1      4
# 29196  57467.855299   10.2         1      6

# %%
def car_passby_cross(car_gps):
    
    #一条新轨迹
    #
    
    return list()#返回一个列表

# %%
df2=df[['vehicle-id','time','x-coordinate','y-coordinate']]
df2.head()
# Out:
#                              vehicle-id        time   x-coordinate  \
# 29194  c243b97c579b441827b59ade5f9c5c3b  1493852410  521579.616152
# 24479  f9643897f57a000c2facc2fe39de8947  1493852411  521461.647074
# 29195  c243b97c579b441827b59ade5f9c5c3b  1493852413  521575.164460
# 24480  f9643897f57a000c2facc2fe39de8947  1493852414  521466.098708
# 29196  c243b97c579b441827b59ade5f9c5c3b  1493852416  521570.712769
#
#        y-coordinate
# 29194  57525.893385
# 24479  56693.716517
# 29195  57498.213683
# 24480  56716.931752
# 29196  57467.855299

# %%
for vid,row in  df2.groupby('vehicle-id'):
#     print(vid)
#     print(row)
    break
row.head()
# Out:
#                               vehicle-id        time   x-coordinate  \
# 282055  000898a7623ce29142a7daeaa7ab0612  1494372159  521411.566353
# 282056  000898a7623ce29142a7daeaa7ab0612  1494372162  521410.453451
# 282057  000898a7623ce29142a7daeaa7ab0612  1494372165  521410.453451
# 282058  000898a7623ce29142a7daeaa7ab0612  1494372168  521410.453451
# 282059  000898a7623ce29142a7daeaa7ab0612  1494372171  521410.453451
#
#         y-coordinate
# 282055  54807.032265
# 282056  54781.138350
# 282057  54749.887073
# 282058  54698.099242
# 282059  54655.240347
